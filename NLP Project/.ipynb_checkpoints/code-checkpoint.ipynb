# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('jd dataset.csv')

# %%
df.head()
# Out:
#       job_id                  job_title             company  \
# 0  JOB103863           Business Analyst            Deloitte
# 1  JOB154438           Business Analyst  Persistent Systems
# 2  JOB259541  Machine Learning Engineer            Deloitte
# 3  JOB134355           Python Developer               Wipro
# 4  JOB154998          Software Engineer           Capgemini
#
#                location                                    job_description  \
# 0   Chennai, Tamil Nadu  We are hiring a Business Analyst at Deloitte i...
# 1                   NaN  We are hiring a Business Analyst at Persistent...
# 2   Nagpur, Maharashtra  We are hiring a Machine Learning Engineer at D...
# 3         Remote, India  We are hiring a Python Developer at Wipro in R...
# 4  Bengaluru, Karnataka  We are hiring a Software Engineer at Capgemini...
#
#    experience                education salary_lpa    job_type  \
# 0   1-3 years  Be Computer Engineering        5.5    Contract
# 1   5-8 years                      MCA        8.5  Internship
# 2  8-12 years                      MBA       13.0   Part-time
# 3   1-3 years         MSc Data Science        5.7   Full-time
# 4   2-5 years                      NaN    5.0 LPA    Contract
#
#                                      required_skills
# 0                    SQL, JIRA, Power BI, Statistics
# 1          Tableau, Power BI, Excel, Statistics, SQL
# 2  Python, Scikit-learn, TensorFlow, Machine Lear...
# 3     Python, REST API, Git, Docker, FastAPI, Django
# 4       C++ | Docker | REST API | SQL | Agile | Java

# %%
df.tail()
# Out:
#           job_id          job_title              company  \
# 16845  JOB205549    DevOps Engineer                  IBM
# 16846  JOB140492       Data Analyst    Fractal Analytics
# 16847  JOB086107  Software Engineer              Cognida
# 16848  JOB266722       Data Analyst             Deloitte
# 16849  JOB148566   Python Developer  Walmart Global Tech
#
#                    location  \
# 16845  Hyderabad, Telangana
# 16846  Bengaluru, Karnataka
# 16847  Noida, Uttar Pradesh
# 16848   Nashik, Maharashtra
# 16849  Bengaluru, Karnataka
#
#                                          job_description  experience  \
# 16845  We are hiring a DevOps Engineer at IBM in Hyde...   0-1 years
# 16846  We are hiring a Data Analyst at Fractal Analyt...   1-3 years
# 16847  We are hiring a Software Engineer at Cognida i...   1-3 years
# 16848  We are hiring a Data Analyst at Deloitte in Na...  8-12 years
# 16849  We are hiring a Python Developer at Walmart Gl...   0-1 years
#
#               education salary_lpa     job_type  \
# 16845  MSC DATA SCIENCE        4.7    Part-time
# 16846  BSc Data Science        5.9    Part-time
# 16847               NaN        4.8  Internship
# 16848               BCA       13.4   Internship
# 16849      Any Graduate        4.8     Contract
#
#                                          required_skills
# 16845  Jenkins, AWS, Kubernetes, Docker, CI/CD, Git, ...
# 16846  NumPy, Python, SQL, Pandas, Statistics, Tablea...
# 16847                   Docker, REST API, Java, Git, SQL
# 16848        Excel, Pandas, Python, Power BI, Statistics
# 16849       Docker, Django, REST API, Git, Python, Flask

# %%
df.sample(8)
# Out:
#           job_id           job_title             company  \
# 16672  JOB135813         AI Engineer           Microsoft
# 1308   JOB040751   Software Engineer           Accenture
# 15560  JOB050269        ai engineer   TechNova Solutions
# 10895  JOB206996         AI Engineer              Oracle
# 13021  JOB220230      JAVA DEVELOPER                 TCS
# 12242  JOB284869  Power Bi Developer           Accenture
# 1155   JOB228434       Web Developer           Cognizant
# 15957  JOB213008        NLP Engineer              Amazon
#
#                    location  \
# 16672         Remote, India
# 1308   Bengaluru, Karnataka
# 15560        Remote, India
# 10895  Bengaluru, Karnataka
# 13021   Nagpur, Maharashtra
# 12242   CHENNAI, TAMIL NADU
# 1155                    NaN
# 15957  Hyderabad, Telangana
#
#                                          job_description  experience  \
# 16672  We are hiring a AI Engineer at Microsoft in Re...   2-5 years
# 1308   We are hiring a Software Engineer at Accenture...   1-3 years
# 15560  We are hiring a AI Engineer at TechNova Soluti...   2-5 years
# 10895   We are hiring a AI Engineer at Oracle in Beng...  8-12 years
# 13021  We are hiring a Java Developer at TCS in Nagpu...  8-12 years
# 12242   We are hiring a Power BI Developer at Accentu...  8-12 years
# 1155   We are hiring a Web Developer at Cognizant in ...   2-5 years
# 15957  We are hiring a NLP Engineer at Amazon in Hyde...  8-12 years
#
#                      education salary_lpa      job_type  \
# 16672         Bsc Data Science        5.7      Contract
# 1308   BE Computer Engineering        NaN     Full-time
# 15560             Any Graduate        7.0    Internship
# 10895                      MBA       12.1      Contract
# 13021             Any Graduate       13.7   Internship
# 12242     BSc Computer Science       14.0     Full-time
# 1155              Any Graduate        5.7    Internship
# 15957                      BCA       13.5     Full-time
#
#                                          required_skills
# 16672      Machine Learning, Deep Learning, PyTorch, LLM
# 1308                       Git, Agile, Java, Docker, SQL
# 15560  TensorFlow, Docker, Deep Learning, Python, LLM...
# 10895  Machine Learning, Docker, TensorFlow, LLM, Dee...
# 13021  Java, Microservices, REST API, Hibernate, Dock...
# 12242             Excel, Power Query, ETL, Data Modeling
# 1155   Git, Node.js, CSS, React, MongoDB, JavaScript,...
# 15957                    BERT | NLP | SQL | Transformers

# %%
df.shape
# Out:
# (16850, 10)

# %%
df.columns
# Out:
# Index(['job_id', 'job_title', 'company', 'location', 'job_description',
#        'experience', 'education', 'salary_lpa', 'job_type', 'required_skills'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16850 entries, 0 to 16849
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_id           16850 non-null  object
#  1   job_title        16850 non-null  object
#  2   company          16850 non-null  object
#  3   location         16145 non-null  object
#  4   job_description  16850 non-null  object
#  5   experience       16341 non-null  object
#  6   education        16222 non-null  object
#  7   salary_lpa       16304 non-null  object
#  8   job_type         16850 non-null  object
#  9   required_skills  16432 non-null  object
# dtypes: object(10)
# memory usage: 1.3+ MB

# %%
df["salary_lpa"] = (
    df["salary_lpa"]
    .astype(str)
    .str.replace("₹", "", regex=False)
    .str.replace("LPA", "", case=False, regex=False)
    .str.strip())

df["salary_lpa"] = pd.to_numeric(df["salary_lpa"], errors="coerce")

# %%
df['salary_lpa'].dtype
# Out:
# dtype('float64')

# %%
df.sample(10)
# Out:
#           job_id           job_title              company  \
# 14810  JOB134864      Java Developer              Cognida
# 244    JOB115230       SQL Developer                Bosch
# 7963   JOB172736         AI Engineer                 Zoho
# 1052   JOB292172       SQL Developer    Fractal Analytics
# 14262  JOB173189    Python Developer  Walmart Global Tech
# 8901   JOB210014  Power BI Developer             Deloitte
# 12195  JOB138043   Software Engineer   Persistent Systems
# 141    JOB175535       SQL Developer            Microsoft
# 6204   JOB028916       Data Engineer            Accenture
# 9081   JOB010599       WEB DEVELOPER               Oracle
#
#                     location  \
# 14810   Chennai, Tamil Nadu
# 244                      NaN
# 7963     Mumbai, Maharashtra
# 1052                     NaN
# 14262   Nagpur, Maharashtra
# 8901     Mumbai, Maharashtra
# 12195    Nagpur, Maharashtra
# 141        Pune, Maharashtra
# 6204     Nashik, Maharashtra
# 9081    Bengaluru, Karnataka
#
#                                          job_description  experience  \
# 14810  We are hiring a Java Developer at Cognida in C...  1-3 years
# 244    We are hiring a sql Developer at Bosch in Pune...  8-12 years
# 7963   We are hiring a AI Engineer at Zoho in Mumbai,...   3-6 years
# 1052   We are hiring a SQL Developer at Fractal Analy...   3-6 years
# 14262  We are hiring a Python Developer at Walmart Gl...   1-3 years
# 8901   We are hiring a Power BI Developer at Deloitte...   3-6 years
# 12195  We are hiring a Software Engineer at Persisten...  8-12 years
# 141    We are hiring a sql Developer at Microsoft in ...   3-6 years
# 6204   We are hiring a Data Engineer at Accenture in ...   0-1 years
# 9081   We are hiring a Web Developer at Oracle in Ben...   1-3 years
#
#                      education  salary_lpa    job_type  \
# 14810        BSc Data Science          4.1   Full-time
# 244               Any Graduate        13.2    Contract
# 7963                       MCA         7.9   Full-time
# 1052    BTech Computer Science         7.3  Internship
# 14262         MSc Data Science         5.1   Full-time
# 8901              Any Graduate         8.3    Contract
# 12195                      MBA        12.6    Contract
# 141           BSc Data Science         8.4   Full-time
# 6204    BTech Computer Science         4.8   Part-time
# 9081   BE Computer Engineering         NaN   Full-time
#
#                                          required_skills
# 14810  Docker, Microservices, Spring Boot, SQL, Java,...
# 244                         Python, SQL Server, ETL, SQL
# 7963   Python, Deep Learning, Machine Learning, LLM, ...
# 1052       Database Design | Python | MySQL | SQL Server
# 14262  SQL, FastAPI, Flask, Django, Python, Git, Dock...
# 8901   Power Query | Excel | SQL | DAX | ETL | Data M...
# 12195       C++, Docker, SQL, Agile, Git, REST API, Java
# 141    ETL, SQL, SQL Server, MySQL, Database Design, ...
# 6204                       Airflow | AWS | Spark | Azure
# 9081          Node.js, Git, MongoDB, CSS, HTML, REST API

# %%
df.isnull().sum()
# Out:
# job_id               0
# job_title            0
# company              0
# location           705
# job_description      0
# experience         509
# education          628
# salary_lpa         548
# job_type             0
# required_skills    418
# dtype: int64

# %%
missing_per = (df.isnull().sum() / len(df)) * 100
missing_per
# Out:
# job_id             0.000000
# job_title          0.000000
# company            0.000000
# location           4.183976
# job_description    0.000000
# experience         3.020772
# education          3.727003
# salary_lpa         3.252226
# job_type           0.000000
# required_skills    2.480712
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(256)

# %%
df[df.duplicated()]
# Out:
#           job_id           job_title            company             location  \
# 541    JOB282810  Power BI Developer            mphasis    Gurugram, Haryana
# 793    JOB265896  Power BI Developer  Fractal Analytics  Chennai, Tamil Nadu
# 949    JOB060827       Data Engineer            Infosys  Nagpur, Maharashtra
# 1238   JOB074285      Web Developer                Zoho  Chennai, Tamil Nadu
# 1511   JOB139250       SQL Developer            HCLTech    Pune, Maharashtra
# ...          ...                 ...                ...                  ...
# 16636  JOB012541      Java Developer        LTIMindtree  Chennai, Tamil Nadu
# 16637  JOB287985    Python Developer        LTIMindtree    Gurugram, Haryana
# 16652  JOB176147       Data Engineer        LTIMindtree  Nashik, Maharashtra
# 16813  JOB215186      Java Developer            Infosys  Nagpur, Maharashtra
# 16841  JOB084782        NLP Engineer  Fractal Analytics         Delhi, India
#
#                                          job_description  experience  \
# 541    We are hiring a Power BI Developer at Mphasis ...   3-6 years
# 793    We are hiring a Power BI Developer at Fractal ...   3-6 years
# 949    We are hiring a Data Engineer at Infosys in Na...  8-12 years
# 1238   We are hiring a Web Developer at Zoho in Chenn...   5-8 years
# 1511    We are hiring a SQL Developer at HCLTech in P...   5-8 years
# ...                                                  ...         ...
# 16636  We are hiring a Java Developer at LTIMindtree ...   2-5 years
# 16637  We are hiring a Python Developer at LTIMindtre...   5-8 years
# 16652  We are hiring a Data Engineer at LTIMindtree i...   1-3 years
# 16813  We are hiring a Java Developer at Infosys in N...  8-12 years
# 16841  We are hiring a NLP Engineer at Fractal Analyt...   5-8 years
#
#                     education  salary_lpa    job_type  \
# 541    BTech Computer Science         7.7   Full-time
# 793                       MBA         6.7   Part-time
# 949          MSc Data Science        12.6   Full-time
# 1238                      BCA        10.0  Internship
# 1511     BSc Computer Science        10.2   Full-time
# ...                       ...         ...         ...
# 16636        BSc Data Science         5.4   Full-time
# 16637        MSc Data Science        10.3  Internship
# 16652            Any Graduate         4.3   Part-time
# 16813            Any Graduate         NaN  Internship
# 16841                     MCA         8.8   Full-time
#
#                                          required_skills
# 541    Power Query, DAX, ETL, Data Modeling, Excel, P...
# 793     Data Modeling, Excel, SQL, DAX, Power Query, ETL
# 949    SQL, Airflow, ETL, Spark, Python, AWS, Azure, ...
# 1238   Node.js, HTML, REST API, JavaScript, MongoDB, ...
# 1511   MySQL, PostgreSQL, SQL Server, Database Design...
# ...                                                  ...
# 16636                     Docker, Spring Boot, Java, SQL
# 16637                REST API, SQL, Django, Git, FastAPI
# 16652  Databricks | Spark | SQL | Azure | AWS | Airfl...
# 16813             Hibernate, Java, Spring Boot, REST API
# 16841  NLP, Machine Learning, NLTK, spaCy, BERT, SQL,...
#
# [256 rows x 10 columns]

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# job_id               0
# job_title            0
# company              0
# location           697
# job_description      0
# experience         503
# education          621
# salary_lpa         535
# job_type             0
# required_skills    412
# dtype: int64

# %%
df['location'] = df['location'].fillna('Unknown')

# %%
df['education'] = df['education'].fillna('Not Specified')

# %%
df['salary_lpa'] = df['salary_lpa'].fillna(df['salary_lpa'].median())

# %%
df.isnull().sum()
# Out:
# job_id               0
# job_title            0
# company              0
# location             0
# job_description      0
# experience         503
# education            0
# salary_lpa           0
# job_type             0
# required_skills    412
# dtype: int64

# %%
df.shape
# Out:
# (16594, 10)

# %%
df['experience'].unique()
# Out:
# array(['1-3 years', '5-8 years', '8-12 years', '2-5 years', '8-12 years ',
#        '3-6 years', ' 5-8 years ', '3-6 years ', '0-1 years', nan,
#        '5-8 years ', ' 1-3 years ', '0-1 years ', ' 0-1 years ',
#        ' 8-12 years', ' 5-8 years', '1-3 years ', ' 2-5 years ',
#        ' 3-6 years ', '2-5 years ', ' 1-3 years', ' 0-1 years',
#        ' 3-6 years', ' 8-12 years ', ' 2-5 years'], dtype=object)

# %%
df['experience'] = (
    df['experience']
    .astype(str)
    .str.replace("years", "", case=False, regex=False) 
    .str.strip())

# %%
df['experience'].unique()
# Out:
# array(['1-3', '5-8', '8-12', '2-5', '3-6', '0-1', 'nan'], dtype=object)

# %%
df["experience"] = df["experience"].replace("nan", np.nan)

# %%
df["experience_avg"] = df["experience"].apply(
    lambda x: (float(x.split("-")[0]) + float(x.split("-")[1])) / 2
    if pd.notna(x) else np.nan
)

# %%
avg_experience = round(df["experience_avg"].mean(),1)

print(avg_experience)
# Out:
# 4.5

# %%
df["experience_avg"] = df["experience_avg"].fillna(avg_experience)

# %%
df.sample(10)
# Out:
#           job_id           job_title             company  \
# 387    JOB245100       Web Developer   Fractal Analytics
# 8553   JOB133237       Sql Developer             HCLTech
# 14920  JOB193559       Web Developer              Oracle
# 10686  JOB149231    Python Developer                 TCS
# 11570  JOB017412    Python Developer           Microsoft
# 8816   JOB199576         AI Engineer   Fractal Analytics
# 2527   JOB274552      Java Developer             HCLTech
# 3275   JOB292875       Web Developer             Siemens
# 8902   JOB099960    Python Developer  Persistent Systems
# 12242  JOB284869  Power Bi Developer           Accenture
#
#                    location  \
# 387     Chennai, Tamil Nadu
# 8553     Pune, Maharashtra
# 14920   Nagpur, Maharashtra
# 10686               Unknown
# 11570         Remote, India
# 8816   Noida, Uttar Pradesh
# 2527   hyderabad, telangana
# 3275   Bengaluru, Karnataka
# 8902    Nashik, Maharashtra
# 12242   CHENNAI, TAMIL NADU
#
#                                          job_description experience  \
# 387    We are hiring a Web Developer at Fractal Analy...        1-3
# 8553    We are hiring a SQL Developer at HCLTech in P...        2-5
# 14920  We are hiring a Web Developer at Oracle in Nag...       8-12
# 10686  We are hiring a Python Developer at TCS in Pun...        3-6
# 11570  We are hiring a Python Developer at Microsoft ...        2-5
# 8816   We are hiring a AI Engineer at Fractal Analyti...        5-8
# 2527   We are hiring a Java Developer at HCLTech in H...       8-12
# 3275   We are hiring a Web Developer at Siemens in Be...        2-5
# 8902   We are hiring a Python Developer at Persistent...        3-6
# 12242   We are hiring a Power BI Developer at Accentu...       8-12
#
#                     education  salary_lpa    job_type  \
# 387          bsc data science         5.9   Part-time
# 8553                      MCA         5.1   Part-time
# 14920                     BCA        12.0  PART-TIME
# 10686                     MBA         6.6  Internship
# 11570            Any Graduate         7.0    Contract
# 8816   BTECH COMPUTER SCIENCE        10.4  Internship
# 2527                      MBA        13.5  Internship
# 3275   BTech Computer Science         5.7  Internship
# 8902             Any Graduate         7.1   Full-time
# 12242    BSc Computer Science        14.0   Full-time
#
#                                          required_skills  experience_avg
# 387                          React, CSS, JavaScript, Git             2.0
# 8553          SQL, PostgreSQL, MySQL, Python, SQL Server             3.5
# 14920           Git, REST API, Node.js, HTML, React, CSS            10.0
# 10686      FastAPI, Docker, Flask, SQL, REST API, Python             4.5
# 11570  SQL, Python, Git, Docker, Flask, REST API, Dja...             3.5
# 8816          NLP, Docker, Machine Learning, LLM, Python             6.5
# 2527   SQL, Hibernate, Microservices, Spring Boot, Ja...            10.0
# 3275              CSS, REST API, HTML, React, JavaScript             3.5
# 8902                Python, Docker, Git, Django, FastAPI             4.5
# 12242             Excel, Power Query, ETL, Data Modeling            10.0

# %%
df.isnull().sum()
# Out:
# job_id               0
# job_title            0
# company              0
# location             0
# job_description      0
# experience         503
# education            0
# salary_lpa           0
# job_type             0
# required_skills    412
# experience_avg       0
# dtype: int64

# %%
df[df["experience"].isna()]
# Out:
#           job_id                  job_title        company  \
# 37     JOB007629              Sql Developer         Amazon
# 65     JOB076910              Web Developer          Wipro
# 154    JOB281207          Software Engineer            TCS
# 167    JOB093014              Data Engineer            IBM
# 169    JOB278081           Business Analyst        HCLTech
# ...          ...                        ...            ...
# 16649  JOB051709  Machine Learning Engineer            IBM
# 16665  JOB130881          Software Engineer      Microsoft
# 16773  JOB000001            DevOps Engineer          Wipro
# 16816  JOB072240         Power BI Developer        Amazon
# 16840  JOB219711               Data Analyst  TECH MAHINDRA
#
#                     location  \
# 37       Nashik, Maharashtra
# 65      Hyderabad, Telangana
# 154     Nagpur, Maharashtra
# 167       Ahmedabad, Gujarat
# 169                  Unknown
# ...                      ...
# 16649      Pune, Maharashtra
# 16665          Remote, India
# 16773      PUNE, MAHARASHTRA
# 16816           delhi, india
# 16840   Hyderabad, Telangana
#
#                                          job_description experience  \
# 37     We are hiring a SQL Developer at Amazon in Nas...        NaN
# 65     We are hiring a Web Developer at Wipro in Hyde...        NaN
# 154    We are hiring a Software Engineer at TCS in Na...        NaN
# 167     We are hiring a Data Engineer at IBM in Ahmed...        NaN
# 169    We are hiring a Business Analyst at HCLTech in...        NaN
# ...                                                  ...        ...
# 16649  We are hiring a Machine Learning Engineer at I...        NaN
# 16665  We are hiring a Software Engineer at Microsoft...        NaN
# 16773   We are hiring a DevOps Engineer at Wipro in P...        NaN
# 16816  We are hiring a Power BI Developer at Amazon i...        NaN
# 16840  We are hiring a Data Analyst at Tech Mahindra ...        NaN
#
#                      education  salary_lpa    job_type  \
# 37        BSc Computer Science        13.5  Internship
# 65      BTech Computer Science        10.4    Contract
# 154                        MBA         6.2    Contract
# 167     BTech Computer Science         5.1    Contract
# 169           BSc Data Science        12.5   Part-time
# ...                        ...         ...         ...
# 16649        MSc Data Science          6.7    Contract
# 16665        bsc data science          3.2   Part-time
# 16773  BE Computer Engineering        11.8  Part-time
# 16816         MSc Data Science         8.1   Part-time
# 16840  Be Computer Engineering         8.2   Full-time
#
#                                          required_skills  experience_avg
# 37     SQL Server, Python, SQL, Database Design, ETL,...             4.5
# 65     Git, REST API, React, HTML, JavaScript, CSS, M...             4.5
# 154                      Docker, REST API, SQL, Git, C++             4.5
# 167    SQL, AWS, Azure, Databricks, Airflow, ETL, Spa...             4.5
# 169             Business Analysis, JIRA, SQL, Statistics             4.5
# ...                                                  ...             ...
# 16649  Machine Learning, SQL, Python, TensorFlow, Docker             4.5
# 16665                    C++, SQL, Git, Docker, REST API             4.5
# 16773             Kubernetes, AWS, Linux, Git, Terraform             4.5
# 16816               Data Modeling, DAX, Power Query, ETL             4.5
# 16840      Power BI, Tableau, Pandas, SQL, NumPy, Python             4.5
#
# [503 rows x 11 columns]

# %%
df = df.dropna(subset=['required_skills']).reset_index(drop=True)

# %%
df['experience'] = df['experience'].fillna(round(df['experience_avg'].mean(),1))

# %%
df.iloc[[37,65]]
# Out:
#        job_id           job_title    company              location  \
# 37  JOB007629       Sql Developer     Amazon   Nashik, Maharashtra
# 65  JOB024784  Power BI Developer   HCLTech   Noida, Uttar Pradesh
#
#                                       job_description experience  \
# 37  We are hiring a SQL Developer at Amazon in Nas...        4.5
# 65  We are hiring a Power BI Developer at HCLTech ...        2-5
#
#                education  salary_lpa    job_type  \
# 37  BSc Computer Science        13.5  Internship
# 65                   MBA         6.7   Part-time
#
#                                       required_skills  experience_avg
# 37  SQL Server, Python, SQL, Database Design, ETL,...             4.5
# 65                     Data Modeling, Excel, SQL, ETL             3.5

# %%
df.isnull().sum()
# Out:
# job_id             0
# job_title          0
# company            0
# location           0
# job_description    0
# experience         0
# education          0
# salary_lpa         0
# job_type           0
# required_skills    0
# experience_avg     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16182 entries, 0 to 16181
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_id           16182 non-null  object
#  1   job_title        16182 non-null  object
#  2   company          16182 non-null  object
#  3   location         16182 non-null  object
#  4   job_description  16182 non-null  object
#  5   experience       16182 non-null  object
#  6   education        16182 non-null  object
#  7   salary_lpa       16182 non-null  float64
#  8   job_type         16182 non-null  object
#  9   required_skills  16182 non-null  object
#  10  experience_avg   16182 non-null  float64
# dtypes: float64(2), object(9)
# memory usage: 1.4+ MB

# %% [markdown]
# # EDA

# %%
no_job = df['job_id'].count()
print('Number Of Jobs :',no_job)
# Out:
# Number Of Jobs : 16182

# %%
n_unique_job_t = df['job_title'].nunique()
print('Number of unique job titles :',n_unique_job_t)
# Out:
# Number of unique job titles : 176

# %%
df['job_title'].value_counts().head(10)
# Out:
# job_title
# Cloud Engineer       975
# Software Engineer    960
# Web Developer        956
# Business Analyst     915
# AI Engineer          911
# Python Developer     906
# Data Analyst         901
# Data Scientist       897
# Java Developer       894
# SQL Developer        893
# Name: count, dtype: int64

# %%
job_by_location = df['location'].value_counts()
job_by_location.head(10)
# Out:
# location
# Remote, India           1145
# Ahmedabad, Gujarat      1122
# Hyderabad, Telangana    1110
# Nashik, Maharashtra     1110
# Pune, Maharashtra       1101
# Mumbai, Maharashtra     1099
# Gurugram, Haryana       1097
# Nagpur, Maharashtra     1086
# Noida, Uttar Pradesh    1085
# Delhi, India            1068
# Name: count, dtype: int64

# %%
df['description_length'] = df['job_description'].str.len()

# %%
avg_desc_len =df['description_length'].mean()
print('Average Description Length :',avg_desc_len)
# Out:
# Average Description Length : 561.5342355703868

# %%
min_desc_len = df['description_length'].min()
print('Minimum Description Length :',min_desc_len)
# Out:
# Minimum Description Length : 475

# %%
max_desc_len = df['description_length'].max()
print('Maximum Description Length :',max_desc_len)
# Out:
# Maximum Description Length : 707

# %%
df['description_length'].describe()
# Out:
# count    16182.000000
# mean       561.534236
# std         31.834863
# min        475.000000
# 25%        539.000000
# 50%        559.000000
# 75%        582.000000
# max        707.000000
# Name: description_length, dtype: float64

# %%
df.isnull().sum()
# Out:
# job_id                0
# job_title             0
# company               0
# location              0
# job_description       0
# experience            0
# education             0
# salary_lpa            0
# job_type              0
# required_skills       0
# experience_avg        0
# description_length    0
# dtype: int64

# %%
unique_companies = df['company'].nunique()
print("Unique Companies:", unique_companies)
# Out:
# Unique Companies: 212

# %%
unique_locations = df['location'].nunique()
print("Unique Locations:", unique_locations)
# Out:
# Unique Locations: 126

# %%
avg_salary = df['salary_lpa'].mean()
print("Average Salary in LPA:", round(avg_salary,2))
# Out:
# Average Salary in LPA: 8.04

# %%
plt.figure(figsize=(10, 5))
df['job_title'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Job Titles')
plt.xlabel('Job Title')
plt.ylabel('Number of Jobs')
plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(10, 5))
df['location'].value_counts().head(10).plot(kind='barh')
plt.title('Top 10 Job Locations')
plt.ylabel('Location')
plt.xlabel('Number of Jobs')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.hist(df['description_length'], bins=30)
plt.title('Job Description Length Distribution')
plt.xlabel('Description Length')
plt.ylabel('Number of Jobs')
plt.show()

# %%
plt.figure(figsize=(10, 5))
df['company'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Companies')
plt.xlabel('Company')
plt.ylabel('Number of Jobs')
plt.xticks(rotation=45)
plt.show()

# %%
top_5_education = df['education'].value_counts().head(5)
print(top_5_education)
# Out:
# education
# BCA                       1488
# BSc Computer Science      1473
# BTech Computer Science    1456
# MBA                       1431
# BSc Data Science          1416
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 5))
top_5_education.plot(kind='bar')
plt.title('Top 5 Education Requirements by Number of Jobs')
plt.xlabel('Education')
plt.ylabel('Number of Jobs')
plt.xticks(rotation=20)
plt.show()

# %%
top_skills = df['required_skills'].value_counts()
top_skills.head(5)
# Out:
# required_skills
# SQL, PyTorch, Docker, TensorFlow       3
# Git, Linux, CI/CD, Docker              3
# Data Modeling, Excel, SQL, ETL, DAX    3
# Git, Java, SQL, REST API               3
# ETL, Excel, Power BI, Power Query      3
# Name: count, dtype: int64

# %%
import re 
def clean_text(text): 
    text = str(text)
    text = re.sub(r"http\S+", "", text) 
    text = re.sub(r"<.*?>", "", text) 
    text = re.sub(r"\S+@\S+", "", text) 
    text = re.sub(r"[^a-zA-Z0-9\s]", " ", text) 
    text = re.sub(r"\s+", " ", text) 
    return text.strip().lower()

# %%
df['job_description'].head()
# Out:
# 0    We are hiring a Business Analyst at Deloitte i...
# 1    We are hiring a Business Analyst at Persistent...
# 2    We are hiring a Machine Learning Engineer at D...
# 3    We are hiring a Python Developer at Wipro in R...
# 4    We are hiring a Software Engineer at Capgemini...
# Name: job_description, dtype: object

# %%
df['clean_description'] = df['job_description'].apply(clean_text)

# %%
df['clean_description'].head()
# Out:
# 0    we are hiring a business analyst at deloitte i...
# 1    we are hiring a business analyst at persistent...
# 2    we are hiring a machine learning engineer at d...
# 3    we are hiring a python developer at wipro in r...
# 4    we are hiring a software engineer at capgemini...
# Name: clean_description, dtype: object

# %%
print(df.iloc[2]['job_description'])
# Out:
# We are hiring a Machine Learning Engineer at Deloitte in Nagpur, Maharashtra. The role requires 8-12 years of experience and MBA or a related qualification. The candidate will develop and maintain solutions related to machine learning engineer, and work on projects involving TensorFlow, Scikit-learn, Machine Learning, AWS, Python, SQL. Key responsibilities include write documentation and perform testing, solving technical problems, improving performance, and communicating results. Experience with TensorFlow, Scikit-learn, Machine Learning, AWS, Python, SQL is preferred. This is a part-time opportunity.

# %%
print(df.iloc[5]['job_description'])
# Out:
# We are hiring a Business Analyst at Persistent Systems in Bengaluru, Karnataka. The role requires 8-12 years of experience and BCA or a related qualification. The candidate will develop and maintain solutions related to business analyst, and work on projects involving Statistics, Tableau, SQL, Power BI, Excel, JIRA. Key responsibilities include analyze business requirements and convert them into technical solutions, solving technical problems, improving performance, and communicating results. Experience with Statistics, Tableau, SQL, Power BI, Excel, JIRA is preferred. This is a full-time opportunity.

# %%
print(df.iloc[2]['clean_description'])
# Out:
# we are hiring a machine learning engineer at deloitte in nagpur maharashtra the role requires 8 12 years of experience and mba or a related qualification the candidate will develop and maintain solutions related to machine learning engineer and work on projects involving tensorflow scikit learn machine learning aws python sql key responsibilities include write documentation and perform testing solving technical problems improving performance and communicating results experience with tensorflow scikit learn machine learning aws python sql is preferred this is a part time opportunity

# %%
df.shape
# Out:
# (16182, 13)

# %% [markdown]
# ### Skill Taxonomy

# %%
skill_taxonomy = {
    "Programming": [
        "Python", "Java", "C", "C++", "C#", "JavaScript",
        "TypeScript", "R", "Go", "Rust", "PHP", "Ruby",
        "Kotlin", "Swift", "Scala", "MATLAB"],
    "Database": [
        "SQL", "MySQL", "PostgreSQL", "Oracle", "SQL Server",
        "SQLite", "MongoDB", "Cassandra", "Redis", "Firebase",
        "DynamoDB", "MariaDB", "Neo4j"],
    "Data Analytics": [
        "Pandas", "NumPy", "Excel", "Power BI", "Tableau",
        "Qlik Sense", "Looker", "Looker Studio", "Plotly",
        "Matplotlib", "Seaborn"],
    "Machine Learning": [
        "Scikit-learn", "XGBoost", "LightGBM", "CatBoost",
        "Random Forest", "Linear Regression", "Logistic Regression",
        "Decision Tree", "KNN", "SVM", "Naive Bayes",
        "Clustering", "K-Means", "PCA"],
    "Deep Learning": [
        "TensorFlow", "PyTorch", "Keras", "OpenCV",
        "CNN", "RNN", "LSTM", "GRU", "GAN", "Transformer"],
    "NLP": [
        "NLTK", "spaCy", "Hugging Face", "Transformers",
        "BERT", "RoBERTa", "GPT", "Word2Vec", "GloVe",
        "FastText", "Text Classification",
        "Named Entity Recognition", "Sentiment Analysis",
        "Text Summarization", "Tokenization", "TF-IDF"],
    "Cloud": [
        "AWS", "Azure", "GCP", "Amazon EC2", "Amazon S3",
        "AWS Lambda", "AWS Glue", "AWS RDS",
        "Azure Data Factory", "Azure Blob Storage",
        "Azure Synapse", "Google BigQuery",
        "Google Cloud Storage", "Google Cloud Functions"],
    "Big Data": [
        "Spark", "PySpark", "Hadoop", "Hive", "Kafka",
        "Flink", "Databricks", "HBase", "Sqoop"],
    "DevOps": [
        "Docker", "Kubernetes", "Jenkins", "Git", "GitHub",
        "GitLab", "Bitbucket", "CI/CD", "Terraform",
        "Ansible", "Docker Compose"],
    "Web Development": [
        "HTML", "CSS", "React", "Angular", "Vue.js",
        "Node.js", "Express.js", "Flask", "Django",
        "FastAPI", "REST API"],
    "Data Engineering": [
        "Apache Airflow", "ETL", "ELT", "Data Pipeline",
        "Data Warehouse", "Snowflake", "Redshift",
        "Azure Data Factory", "AWS Glue",
        "Databricks", "BigQuery", "Azure Synapse"],
    "Generative AI": [
        "Generative AI", "Large Language Models", "LLM",
        "LangChain", "LlamaIndex", "OpenAI API", "RAG",
        "Vector Database", "FAISS", "ChromaDB",
        "Pinecone", "Prompt Engineering", "Embeddings",
        "Sentence Transformers"]}

# %%
len(skill_taxonomy)
# Out:
# 12

# %%
skill_taxonomy["Programming"]
# Out:
# ['Python',
#  'Java',
#  'C',
#  'C++',
#  'C#',
#  'JavaScript',
#  'TypeScript',
#  'R',
#  'Go',
#  'Rust',
#  'PHP',
#  'Ruby',
#  'Kotlin',
#  'Swift',
#  'Scala',
#  'MATLAB']

# %%
skill_taxonomy["Database"]
# Out:
# ['SQL',
#  'MySQL',
#  'PostgreSQL',
#  'Oracle',
#  'SQL Server',
#  'SQLite',
#  'MongoDB',
#  'Cassandra',
#  'Redis',
#  'Firebase',
#  'DynamoDB',
#  'MariaDB',
#  'Neo4j']

# %%
skill_taxonomy["NLP"]
# Out:
# ['NLTK',
#  'spaCy',
#  'Hugging Face',
#  'Transformers',
#  'BERT',
#  'RoBERTa',
#  'GPT',
#  'Word2Vec',
#  'GloVe',
#  'FastText',
#  'Text Classification',
#  'Named Entity Recognition',
#  'Sentiment Analysis',
#  'Text Summarization',
#  'Tokenization',
#  'TF-IDF']

# %%
total_skills = sum(len(skills) for skills in skill_taxonomy.values())
print("Total Skills:", total_skills)
# Out:
# Total Skills: 151

# %%
skill_aliases = {
    "Python": [
        "python3",
        "python 3"],
    "JavaScript": [
        "javascript",
        "java script",
        "js"],
    "TypeScript": [
        "typescript",
        "ts"],
    "C++": [
        "cpp",
        "c plus plus" ],
    "C#": [
        "c sharp",
        "csharp"],
    "SQL": [
        "structured query language"],
    "PostgreSQL": [
        "postgres",
        "postgresql",
        "postgre"],
    "MongoDB": [
        "mongo",
        "mongodb"],
    "Excel": [
        "ms excel",
        "microsoft excel" ],
    "Power BI": [
        "powerbi",
        "power-bi",
        "power bi"],
    "Scikit-learn": [
        "sklearn",
        "scikit learn",
        "scikit-learn"],
    "TensorFlow": ["tensorflow"],
    "PyTorch": ["pytorch","torch"],
    "Hugging Face": ["huggingface","hugging face"],
    "AWS": ["amazon web services","amazon aws"],
    "Azure": ["microsoft azure"],
    "GCP": ["google cloud","google cloud platform"],
    "Spark": ["apache spark"],
    "PySpark": ["pyspark","apache pyspark"],
    "Hadoop": ["apache hadoop"],
    "Docker": ["docker container"],
    "Kubernetes": ["k8s"],
    "GitHub": ["github","git hub"],
    "FastAPI": ["fast api"],
    "OpenAI API": ["openai api", "openai"],
    "LangChain": ["lang chain"],
    "Power BI": ["powerbi","power-bi"]
}

# %%
rows = []
for category, skills in skill_taxonomy.items():
    for skill in skills:
        aliases = skill_aliases.get(skill, [])
        rows.append({
            "skill": skill,
            "category": category,
            "aliases": ", ".join(aliases)})
skill_df = pd.DataFrame(rows)

# %%
skill_df.head()
# Out:
#     skill     category            aliases
# 0  Python  Programming  python3, python 3
# 1    Java  Programming
# 2       C  Programming
# 3     C++  Programming   cpp, c plus plus
# 4      C#  Programming    c sharp, csharp

# %% [markdown]
#  NLP Text Preprocessing

# %%
import nltk
import spacy
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Error loading punkt: <urlopen error pathsec.urlopen: no
# [nltk_data]     validated address for host
# [nltk_data]     'raw.githubusercontent.com'; refusing to connect by
# [nltk_data]     unvalidated hostname>
# [nltk_data] Error loading punkt_tab: <urlopen error pathsec.urlopen:
# [nltk_data]     no validated address for host
# [nltk_data]     'raw.githubusercontent.com'; refusing to connect by
# [nltk_data]     unvalidated hostname>
# [nltk_data] Error loading stopwords: <urlopen error pathsec.urlopen:
# [nltk_data]     no validated address for host
# [nltk_data]     'raw.githubusercontent.com'; refusing to connect by
# [nltk_data]     unvalidated hostname>
# [nltk_data] Error loading wordnet: <urlopen error pathsec.urlopen: no
# [nltk_data]     validated address for host
# [nltk_data]     'raw.githubusercontent.com'; refusing to connect by
# [nltk_data]     unvalidated hostname>
# [nltk_data] Error loading omw-1.4: <urlopen error pathsec.urlopen: no
# [nltk_data]     validated address for host
# [nltk_data]     'raw.githubusercontent.com'; refusing to connect by
# [nltk_data]     unvalidated hostname>
# False

# %%
df['clean_description'].head()
# Out:
# 0    we are hiring a business analyst at deloitte i...
# 1    we are hiring a business analyst at persistent...
# 2    we are hiring a machine learning engineer at d...
# 3    we are hiring a python developer at wipro in r...
# 4    we are hiring a software engineer at capgemini...
# Name: clean_description, dtype: object

# %%
print(df['clean_description'].iloc[0])
# Out:
# we are hiring a business analyst at deloitte in chennai tamil nadu the role requires 1 3 years of experience and be computer engineering or a related qualification the candidate will build reports dashboards models or automated workflows and work on projects involving power bi sql jira statistics key responsibilities include write documentation and perform testing solving technical problems improving performance and communicating results experience with power bi sql jira statistics is preferred this is a contract opportunity

# %%
text = df['clean_description'].iloc[0]
lower_text = text.lower()
print(lower_text)
# Out:
# we are hiring a business analyst at deloitte in chennai tamil nadu the role requires 1 3 years of experience and be computer engineering or a related qualification the candidate will build reports dashboards models or automated workflows and work on projects involving power bi sql jira statistics key responsibilities include write documentation and perform testing solving technical problems improving performance and communicating results experience with power bi sql jira statistics is preferred this is a contract opportunity

# %%
tokens = word_tokenize(lower_text)
print(tokens)
# Out:
# ['we', 'are', 'hiring', 'a', 'business', 'analyst', 'at', 'deloitte', 'in', 'chennai', 'tamil', 'nadu', 'the', 'role', 'requires', '1', '3', 'years', 'of', 'experience', 'and', 'be', 'computer', 'engineering', 'or', 'a', 'related', 'qualification', 'the', 'candidate', 'will', 'build', 'reports', 'dashboards', 'models', 'or', 'automated', 'workflows', 'and', 'work', 'on', 'projects', 'involving', 'power', 'bi', 'sql', 'jira', 'statistics', 'key', 'responsibilities', 'include', 'write', 'documentation', 'and', 'perform', 'testing', 'solving', 'technical', 'problems', 'improving', 'performance', 'and', 'communicating', 'results', 'experience', 'with', 'power', 'bi', 'sql', 'jira', 'statistics', 'is', 'preferred', 'this', 'is', 'a', 'contract', 'opportunity']

# %%
stop_words = set(stopwords.words('english'))

# %%
filtered_tokens = []
for word in tokens:
    if word not in stop_words:
        filtered_tokens.append(word)
print(filtered_tokens)
# Out:
# ['hiring', 'business', 'analyst', 'deloitte', 'chennai', 'tamil', 'nadu', 'role', 'requires', '1', '3', 'years', 'experience', 'computer', 'engineering', 'related', 'qualification', 'candidate', 'build', 'reports', 'dashboards', 'models', 'automated', 'workflows', 'work', 'projects', 'involving', 'power', 'bi', 'sql', 'jira', 'statistics', 'key', 'responsibilities', 'include', 'write', 'documentation', 'perform', 'testing', 'solving', 'technical', 'problems', 'improving', 'performance', 'communicating', 'results', 'experience', 'power', 'bi', 'sql', 'jira', 'statistics', 'preferred', 'contract', 'opportunity']

# %%
lemmatizer = WordNetLemmatizer()

# %%
lemmatized_tokens = []
for word in filtered_tokens:
    lemma = lemmatizer.lemmatize(word)
    lemmatized_tokens.append(lemma)
print(lemmatized_tokens)
# Out:
# ['hiring', 'business', 'analyst', 'deloitte', 'chennai', 'tamil', 'nadu', 'role', 'requires', '1', '3', 'year', 'experience', 'computer', 'engineering', 'related', 'qualification', 'candidate', 'build', 'report', 'dashboard', 'model', 'automated', 'workflow', 'work', 'project', 'involving', 'power', 'bi', 'sql', 'jira', 'statistic', 'key', 'responsibility', 'include', 'write', 'documentation', 'perform', 'testing', 'solving', 'technical', 'problem', 'improving', 'performance', 'communicating', 'result', 'experience', 'power', 'bi', 'sql', 'jira', 'statistic', 'preferred', 'contract', 'opportunity']

# %%
stemmer = PorterStemmer()

# %%
stemmed_tokens = []
for word in filtered_tokens:
    stem = stemmer.stem(word)
    stemmed_tokens.append(stem)
print(stemmed_tokens)
# Out:
# ['hire', 'busi', 'analyst', 'deloitt', 'chennai', 'tamil', 'nadu', 'role', 'requir', '1', '3', 'year', 'experi', 'comput', 'engin', 'relat', 'qualif', 'candid', 'build', 'report', 'dashboard', 'model', 'autom', 'workflow', 'work', 'project', 'involv', 'power', 'bi', 'sql', 'jira', 'statist', 'key', 'respons', 'includ', 'write', 'document', 'perform', 'test', 'solv', 'technic', 'problem', 'improv', 'perform', 'commun', 'result', 'experi', 'power', 'bi', 'sql', 'jira', 'statist', 'prefer', 'contract', 'opportun']

# %%
comparison = pd.DataFrame({
    'Original': filtered_tokens,
    'Stemmed': stemmed_tokens,
    'Lemmatized': lemmatized_tokens
})

comparison
# Out:
#             Original    Stemmed      Lemmatized
# 0             hiring       hire          hiring
# 1           business       busi        business
# 2            analyst    analyst         analyst
# 3           deloitte    deloitt        deloitte
# 4            chennai    chennai         chennai
# 5              tamil      tamil           tamil
# 6               nadu       nadu            nadu
# 7               role       role            role
# 8           requires     requir        requires
# 9                  1          1               1
# 10                 3          3               3
# 11             years       year            year
# 12        experience     experi      experience
# 13          computer     comput        computer
# 14       engineering      engin     engineering
# 15           related      relat         related
# 16     qualification     qualif   qualification
# 17         candidate     candid       candidate
# 18             build      build           build
# 19           reports     report          report
# 20        dashboards  dashboard       dashboard
# 21            models      model           model
# 22         automated      autom       automated
# 23         workflows   workflow        workflow
# 24              work       work            work
# 25          projects    project         project
# 26         involving     involv       involving
# 27             power      power           power
# 28                bi         bi              bi
# 29               sql        sql             sql
# 30              jira       jira            jira
# 31        statistics    statist       statistic
# 32               key        key             key
# 33  responsibilities    respons  responsibility
# 34           include     includ         include
# 35             write      write           write
# 36     documentation   document   documentation
# 37           perform    perform         perform
# 38           testing       test         testing
# 39           solving       solv         solving
# 40         technical    technic       technical
# 41          problems    problem         problem
# 42         improving     improv       improving
# 43       performance    perform     performance
# 44     communicating     commun   communicating
# 45           results     result          result
# 46        experience     experi      experience
# 47             power      power           power
# 48                bi         bi              bi
# 49               sql        sql             sql
# 50              jira       jira            jira
# 51        statistics    statist       statistic
# 52         preferred     prefer       preferred
# 53          contract   contract        contract
# 54       opportunity   opportun     opportunity

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(df['clean_description'].iloc[0])

# %%
sentences = [sent.text for sent in doc.sents]
print(sentences)
# Out:
# ['we are hiring a business analyst at deloitte in chennai tamil nadu the role requires 1 3 years of experience and be computer engineering or a related qualification the candidate will build reports dashboards models or automated workflows and work on projects involving power bi sql jira statistics key responsibilities include write documentation and perform testing solving technical problems improving performance and communicating results experience with power bi sql jira statistics is preferred this is a contract opportunity']

# %%
def preprocess_text(text):
    # Lowercase
    text = text.lower()
    # Tokenization
    tokens = word_tokenize(text)
    # Stopword removal
    tokens = [
        word for word in tokens
        if word not in stop_words
    ]
    # Lemmatization
    tokens = [
        lemmatizer.lemmatize(word)
        for word in tokens
    ]
    return tokens

# %%
df['preprocessed_tokens'] = df['clean_description'].apply(preprocess_text)

# %%
df[['clean_description', 'preprocessed_tokens']].head()
# Out:
#                                    clean_description  \
# 0  we are hiring a business analyst at deloitte i...
# 1  we are hiring a business analyst at persistent...
# 2  we are hiring a machine learning engineer at d...
# 3  we are hiring a python developer at wipro in r...
# 4  we are hiring a software engineer at capgemini...
#
#                                  preprocessed_tokens
# 0  [hiring, business, analyst, deloitte, chennai,...
# 1  [hiring, business, analyst, persistent, system...
# 2  [hiring, machine, learning, engineer, deloitte...
# 3  [hiring, python, developer, wipro, remote, ind...
# 4  [hiring, software, engineer, capgemini, bengal...

# %%
df['preprocessed_text'] = df['preprocessed_tokens'].apply(
    lambda x: ' '.join(x))

# %%
df[['clean_description', 'preprocessed_text']].head()
# Out:
#                                    clean_description  \
# 0  we are hiring a business analyst at deloitte i...
# 1  we are hiring a business analyst at persistent...
# 2  we are hiring a machine learning engineer at d...
# 3  we are hiring a python developer at wipro in r...
# 4  we are hiring a software engineer at capgemini...
#
#                                    preprocessed_text
# 0  hiring business analyst deloitte chennai tamil...
# 1  hiring business analyst persistent system remo...
# 2  hiring machine learning engineer deloitte nagp...
# 3  hiring python developer wipro remote india rol...
# 4  hiring software engineer capgemini bengaluru k...

# %% [markdown]
# Build Rule-Based Skill Extractor

# %%
skills = []
for category, skill_list in skill_taxonomy.items():
    skills.extend(skill_list)
print("Total Skills:", len(skills))
# Out:
# Total Skills: 151

# %%
print(skills)
# Out:
# ['Python', 'Java', 'C', 'C++', 'C#', 'JavaScript', 'TypeScript', 'R', 'Go', 'Rust', 'PHP', 'Ruby', 'Kotlin', 'Swift', 'Scala', 'MATLAB', 'SQL', 'MySQL', 'PostgreSQL', 'Oracle', 'SQL Server', 'SQLite', 'MongoDB', 'Cassandra', 'Redis', 'Firebase', 'DynamoDB', 'MariaDB', 'Neo4j', 'Pandas', 'NumPy', 'Excel', 'Power BI', 'Tableau', 'Qlik Sense', 'Looker', 'Looker Studio', 'Plotly', 'Matplotlib', 'Seaborn', 'Scikit-learn', 'XGBoost', 'LightGBM', 'CatBoost', 'Random Forest', 'Linear Regression', 'Logistic Regression', 'Decision Tree', 'KNN', 'SVM', 'Naive Bayes', 'Clustering', 'K-Means', 'PCA', 'TensorFlow', 'PyTorch', 'Keras', 'OpenCV', 'CNN', 'RNN', 'LSTM', 'GRU', 'GAN', 'Transformer', 'NLTK', 'spaCy', 'Hugging Face', 'Transformers', 'BERT', 'RoBERTa', 'GPT', 'Word2Vec', 'GloVe', 'FastText', 'Text Classification', 'Named Entity Recognition', 'Sentiment Analysis', 'Text Summarization', 'Tokenization', 'TF-IDF', 'AWS', 'Azure', 'GCP', 'Amazon EC2', 'Amazon S3', 'AWS Lambda', 'AWS Glue', 'AWS RDS', 'Azure Data Factory', 'Azure Blob Storage', 'Azure Synapse', 'Google BigQuery', 'Google Cloud Storage', 'Google Cloud Functions', 'Spark', 'PySpark', 'Hadoop', 'Hive', 'Kafka', 'Flink', 'Databricks', 'HBase', 'Sqoop', 'Docker', 'Kubernetes', 'Jenkins', 'Git', 'GitHub', 'GitLab', 'Bitbucket', 'CI/CD', 'Terraform', 'Ansible', 'Docker Compose', 'HTML', 'CSS', 'React', 'Angular', 'Vue.js', 'Node.js', 'Express.js', 'Flask', 'Django', 'FastAPI', 'REST API', 'Apache Airflow', 'ETL', 'ELT', 'Data Pipeline', 'Data Warehouse', 'Snowflake', 'Redshift', 'Azure Data Factory', 'AWS Glue', 'Databricks', 'BigQuery', 'Azure Synapse', 'Generative AI', 'Large Language Models', 'LLM', 'LangChain', 'LlamaIndex', 'OpenAI API', 'RAG', 'Vector Database', 'FAISS', 'ChromaDB', 'Pinecone', 'Prompt Engineering', 'Embeddings', 'Sentence Transformers']

# %%
def extract_skills(text):
    found = []
    for skill in skills:
        if skill.lower() in text.lower():
            found.append(skill)
    return found

# %%
df['extracted_skills'] = df['clean_description'].apply(extract_skills)

# %%
df[['job_title', 'clean_description', 'extracted_skills']].head(10)
# Out:
#                    job_title  \
# 0           Business Analyst
# 1           Business Analyst
# 2  Machine Learning Engineer
# 3           Python Developer
# 4          Software Engineer
# 5           Business Analyst
# 6               NLP Engineer
# 7             Java Developer
# 8           Business Analyst
# 9           Python Developer
#
#                                    clean_description  \
# 0  we are hiring a business analyst at deloitte i...
# 1  we are hiring a business analyst at persistent...
# 2  we are hiring a machine learning engineer at d...
# 3  we are hiring a python developer at wipro in r...
# 4  we are hiring a software engineer at capgemini...
# 5  we are hiring a business analyst at persistent...
# 6  we are hiring a nlp engineer at ibm in bengalu...
# 7  we are hiring a java developer at siemens in r...
# 8  we are hiring a business analyst at tcs in del...
# 9  we are hiring a python developer at siemens in...
#
#                                     extracted_skills
# 0                              [C, R, SQL, Power BI]
# 1              [C, R, SQL, Excel, Power BI, Tableau]
# 2               [Python, C, R, SQL, TensorFlow, AWS]
# 3       [Python, C, R, Go, Docker, Django, REST API]
# 4                [Java, C, R, SQL, Docker, REST API]
# 5              [C, R, SQL, Excel, Power BI, Tableau]
# 6    [Python, C, R, Transformer, Transformers, BERT]
# 7                [Java, C, R, Docker, Git, REST API]
# 8                     [C, R, SQL, Power BI, Tableau]
# 9  [Python, C, R, Go, SQL, Docker, Flask, Django,...

# %%
def extract_skills(text):
    text = str(text).lower()
    found = []
    for skill in skills:
        skill_lower = skill.lower()
        pattern = r'\b' + re.escape(skill_lower) + r'\b'
        if re.search(pattern, text):
            found.append(skill)
    return found

# %%
df['extracted_skills'] = df['clean_description'].apply(extract_skills)

# %%
df[['job_title', 'extracted_skills']].head(10)
# Out:
#                    job_title                               extracted_skills
# 0           Business Analyst                                [SQL, Power BI]
# 1           Business Analyst                [SQL, Excel, Power BI, Tableau]
# 2  Machine Learning Engineer                 [Python, SQL, TensorFlow, AWS]
# 3           Python Developer             [Python, Docker, Django, REST API]
# 4          Software Engineer                  [Java, SQL, Docker, REST API]
# 5           Business Analyst                [SQL, Excel, Power BI, Tableau]
# 6               NLP Engineer                   [Python, Transformers, BERT]
# 7             Java Developer                  [Java, Docker, Git, REST API]
# 8           Business Analyst                       [SQL, Power BI, Tableau]
# 9           Python Developer  [Python, SQL, Docker, Flask, Django, FastAPI]

# %%
def extract_skills(text):
    text = str(text).lower()
    found = []
    for skill in skills:
        skill_pattern = r'\b' + re.escape(skill.lower()) + r'\b'
        if re.search(skill_pattern, text):
            found.append(skill)
        else:
            aliases = skill_aliases.get(skill, [])
            for alias in aliases:
                alias_pattern = r'\b' + re.escape(alias.lower()) + r'\b'
                if re.search(alias_pattern, text):
                    found.append(skill)
                    break

    return list(set(found))

# %%
df['extracted_skills'] = df['clean_description'].apply(extract_skills)

# %%
df[['job_title', 'clean_description', 'extracted_skills']].head(10)
# Out:
#                    job_title  \
# 0           Business Analyst
# 1           Business Analyst
# 2  Machine Learning Engineer
# 3           Python Developer
# 4          Software Engineer
# 5           Business Analyst
# 6               NLP Engineer
# 7             Java Developer
# 8           Business Analyst
# 9           Python Developer
#
#                                    clean_description  \
# 0  we are hiring a business analyst at deloitte i...
# 1  we are hiring a business analyst at persistent...
# 2  we are hiring a machine learning engineer at d...
# 3  we are hiring a python developer at wipro in r...
# 4  we are hiring a software engineer at capgemini...
# 5  we are hiring a business analyst at persistent...
# 6  we are hiring a nlp engineer at ibm in bengalu...
# 7  we are hiring a java developer at siemens in r...
# 8  we are hiring a business analyst at tcs in del...
# 9  we are hiring a python developer at siemens in...
#
#                                 extracted_skills
# 0                                [SQL, Power BI]
# 1                [Power BI, Tableau, SQL, Excel]
# 2   [TensorFlow, SQL, Scikit-learn, Python, AWS]
# 3             [Django, REST API, Python, Docker]
# 4                  [Docker, SQL, REST API, Java]
# 5                [Power BI, Tableau, SQL, Excel]
# 6                   [Transformers, BERT, Python]
# 7                  [Docker, Git, Java, REST API]
# 8                       [Tableau, SQL, Power BI]
# 9  [Docker, SQL, Python, Django, Flask, FastAPI]

# %%
extract_skills(text)
# Out:
# ['SQL', 'Power BI']

# %%
df['skill_count'] = df['extracted_skills'].apply(len)

# %%
df[['job_title', 'skill_count']].head(10)
# Out:
#                    job_title  skill_count
# 0           Business Analyst            2
# 1           Business Analyst            4
# 2  Machine Learning Engineer            5
# 3           Python Developer            4
# 4          Software Engineer            4
# 5           Business Analyst            4
# 6               NLP Engineer            3
# 7             Java Developer            4
# 8           Business Analyst            3
# 9           Python Developer            6

# %%
average_skills = df['skill_count'].mean()
print("Average Skills per Job:", average_skills)
# Out:
# Average Skills per Job: 3.9336917562724016

# %%
from collections import Counter

all_skills = []

for skill_list in df['extracted_skills']:
    all_skills.extend(skill_list)

skill_counts = Counter(all_skills)

skill_counts.most_common(10)
# Out:
# [('SQL', 7747),
#  ('Python', 6355),
#  ('Docker', 4677),
#  ('Git', 4006),
#  ('REST API', 2683),
#  ('AWS', 2610),
#  ('Power BI', 2443),
#  ('Excel', 2135),
#  ('ETL', 2090),
#  ('TensorFlow', 1944)]

# %%
top_skills = pd.Series(skill_counts).head(10)
plt.figure(figsize=(10,5))
plt.bar(top_skills.index, top_skills.values)
plt.title("Top 10 Extracted Skills")
plt.xlabel("Skill")
plt.ylabel("Number of Jobs")
plt.xticks(rotation=45)

plt.show()

# %%
skill_category = {}

for category, skill_list in skill_taxonomy.items():

    for skill in skill_list:

        skill_category[skill] = category

# %%
skill_category = {}

for category, skill_list in skill_taxonomy.items():

    for skill in skill_list:

        skill_category[skill] = category

# %%
def get_categories(skill_list):

    categories = []

    for skill in skill_list:

        category = skill_category.get(skill)

        if category:
            categories.append(category)

    return list(set(categories))

# %%
df['skill_categories'] = df['extracted_skills'].apply(get_categories)

# %%
df[['extracted_skills', 'skill_categories']].head(10)
# Out:
#                                 extracted_skills  \
# 0                                [SQL, Power BI]
# 1                [Power BI, Tableau, SQL, Excel]
# 2   [TensorFlow, SQL, Scikit-learn, Python, AWS]
# 3             [Django, REST API, Python, Docker]
# 4                  [Docker, SQL, REST API, Java]
# 5                [Power BI, Tableau, SQL, Excel]
# 6                   [Transformers, BERT, Python]
# 7                  [Docker, Git, Java, REST API]
# 8                       [Tableau, SQL, Power BI]
# 9  [Docker, SQL, Python, Django, Flask, FastAPI]
#
#                                     skill_categories
# 0                         [Data Analytics, Database]
# 1                         [Data Analytics, Database]
# 2  [Programming, Cloud, Database, Deep Learning, ...
# 3             [DevOps, Web Development, Programming]
# 4   [DevOps, Web Development, Programming, Database]
# 5                         [Data Analytics, Database]
# 6                                 [NLP, Programming]
# 7             [DevOps, Programming, Web Development]
# 8                         [Data Analytics, Database]
# 9   [DevOps, Programming, Web Development, Database]

# %% [markdown]
# # Improve Extraction Using Regex and Phrase Matching

# %%
from spacy.matcher import PhraseMatcher

# %%
print("Dataset Shape:", df.shape)
print("Columns:")
print(df.columns.tolist())
# Out:
# Dataset Shape: (16182, 18)
# Columns:
# ['job_id', 'job_title', 'company', 'location', 'job_description', 'experience', 'education', 'salary_lpa', 'job_type', 'required_skills', 'experience_avg', 'description_length', 'clean_description', 'preprocessed_tokens', 'preprocessed_text', 'extracted_skills', 'skill_count', 'skill_categories']

# %%
print(df['clean_description'].head())
# Out:
# 0    we are hiring a business analyst at deloitte i...
# 1    we are hiring a business analyst at persistent...
# 2    we are hiring a machine learning engineer at d...
# 3    we are hiring a python developer at wipro in r...
# 4    we are hiring a software engineer at capgemini...
# Name: clean_description, dtype: object

# %%
print(df['clean_description'].iloc[0])
# Out:
# we are hiring a business analyst at deloitte in chennai tamil nadu the role requires 1 3 years of experience and be computer engineering or a related qualification the candidate will build reports dashboards models or automated workflows and work on projects involving power bi sql jira statistics key responsibilities include write documentation and perform testing solving technical problems improving performance and communicating results experience with power bi sql jira statistics is preferred this is a contract opportunity

# %%
skill_patterns = {}
for skill in skill_taxonomy:
    escaped_skill = re.escape(skill)
    pattern = (
        r"\b" +
        escaped_skill.replace(r"\ ", r"\s+") +
        r"\b")
    skill_patterns[skill] = pattern

# %%
if "Python" in skill_patterns:
    skill_patterns["Python"] = (
        r"\bpython(?:\s*3)?(?:\s+programming)?\b"
    )

# %%
for skill, pattern in list(skill_patterns.items())[:10]:
    print(skill, ":", pattern)
# Out:
# Programming : \bProgramming\b
# Database : \bDatabase\b
# Data Analytics : \bData\s+Analytics\b
# Machine Learning : \bMachine\s+Learning\b
# Deep Learning : \bDeep\s+Learning\b
# NLP : \bNLP\b
# Cloud : \bCloud\b
# Big Data : \bBig\s+Data\b
# DevOps : \bDevOps\b
# Web Development : \bWeb\s+Development\b

# %%
def extract_regex_skills(text):
    found_skills = []
    text = str(text)
    for skill, pattern in skill_patterns.items():
        if re.search(pattern, text, re.IGNORECASE):
            found_skills.append(skill)
    return found_skills

# %%
df['regex_skills'] = df['clean_description'].apply(extract_regex_skills)

# %%
df[['job_title','regex_skills']].head(10)
# Out:
#                    job_title             regex_skills
# 0           Business Analyst                       []
# 1           Business Analyst                       []
# 2  Machine Learning Engineer       [Machine Learning]
# 3           Python Developer                       []
# 4          Software Engineer                       []
# 5           Business Analyst                       []
# 6               NLP Engineer  [Machine Learning, NLP]
# 7             Java Developer                       []
# 8           Business Analyst                       []
# 9           Python Developer                       []

# %%
multi_word_skills = [
    skill
    for skill in skill_taxonomy
    if len(skill.split()) > 1]

# %%
print("Total Multi-word Skills:", len(multi_word_skills))
print("\nMulti-word Skills:")
for skill in multi_word_skills:
    print(skill)
# Out:
# Total Multi-word Skills: 7
#
# Multi-word Skills:
# Data Analytics
# Machine Learning
# Deep Learning
# Big Data
# Web Development
# Data Engineering
# Generative AI

# %%
nlp = spacy.load("en_core_web_sm")

# %%
matcher = PhraseMatcher(nlp.vocab,attr="LOWER")

# %%
patterns = [
    nlp.make_doc(skill)
    for skill in multi_word_skills
]

# %%
matcher.add("SKILLS",patterns)

# %%
def extract_phrase_skills(text):
    doc = nlp(str(text))
    matches = matcher(doc)
    found_skills = []
    for match_id, start, end in matches:
        span = doc[start:end]
        found_skills.append(span.text)
    return list(set(found_skills))

# %%
df['phrase_skills'] = df['clean_description'].apply(extract_phrase_skills)

# %%
df[['job_title','phrase_skills']].head(10)
# Out:
#                    job_title       phrase_skills
# 0           Business Analyst                  []
# 1           Business Analyst                  []
# 2  Machine Learning Engineer  [machine learning]
# 3           Python Developer                  []
# 4          Software Engineer                  []
# 5           Business Analyst                  []
# 6               NLP Engineer  [machine learning]
# 7             Java Developer                  []
# 8           Business Analyst                  []
# 9           Python Developer                  []

# %%
def advanced_skill_extractor(text):
    regex_skills = extract_regex_skills(text)
    phrase_skills = extract_phrase_skills(text)
    all_skills = regex_skills + phrase_skills
    return list(set(all_skills))

# %%
df['advanced_skills'] = df['clean_description'].apply(advanced_skill_extractor)

# %%
df[['job_title','clean_description','advanced_skills']].head(10)
# Out:
#                    job_title  \
# 0           Business Analyst
# 1           Business Analyst
# 2  Machine Learning Engineer
# 3           Python Developer
# 4          Software Engineer
# 5           Business Analyst
# 6               NLP Engineer
# 7             Java Developer
# 8           Business Analyst
# 9           Python Developer
#
#                                    clean_description  \
# 0  we are hiring a business analyst at deloitte i...
# 1  we are hiring a business analyst at persistent...
# 2  we are hiring a machine learning engineer at d...
# 3  we are hiring a python developer at wipro in r...
# 4  we are hiring a software engineer at capgemini...
# 5  we are hiring a business analyst at persistent...
# 6  we are hiring a nlp engineer at ibm in bengalu...
# 7  we are hiring a java developer at siemens in r...
# 8  we are hiring a business analyst at tcs in del...
# 9  we are hiring a python developer at siemens in...
#
#                              advanced_skills
# 0                                         []
# 1                                         []
# 2       [machine learning, Machine Learning]
# 3                                         []
# 4                                         []
# 5                                         []
# 6  [machine learning, NLP, Machine Learning]
# 7                                         []
# 8                                         []
# 9                                         []

# %%
df['advanced_skill_count'] = df['advanced_skills'].apply(len)

# %%
df[['job_title','advanced_skills','advanced_skill_count']].head(10)
# Out:
#                    job_title                            advanced_skills  \
# 0           Business Analyst                                         []
# 1           Business Analyst                                         []
# 2  Machine Learning Engineer       [machine learning, Machine Learning]
# 3           Python Developer                                         []
# 4          Software Engineer                                         []
# 5           Business Analyst                                         []
# 6               NLP Engineer  [machine learning, NLP, Machine Learning]
# 7             Java Developer                                         []
# 8           Business Analyst                                         []
# 9           Python Developer                                         []
#
#    advanced_skill_count
# 0                     0
# 1                     0
# 2                     2
# 3                     0
# 4                     0
# 5                     0
# 6                     3
# 7                     0
# 8                     0
# 9                     0

# %%
from collections import Counter
all_skills = []
for skill_list in df['advanced_skills']:
    all_skills.extend(skill_list)

# %%
skill_counts = Counter(all_skills)

# %%
top_10_skills = skill_counts.most_common(10)
top_10_skills
# Out:
# [('machine learning', 3059),
#  ('Machine Learning', 3059),
#  ('NLP', 1791),
#  ('Cloud', 1141),
#  ('DevOps', 1061),
#  ('Database', 731),
#  ('deep learning', 702),
#  ('Deep Learning', 702)]

# %%
top_skills_df = pd.DataFrame(
    top_10_skills,
    columns=['Skill', 'Job_Count'])
top_skills_df
# Out:
#               Skill  Job_Count
# 0  machine learning       3059
# 1  Machine Learning       3059
# 2               NLP       1791
# 3             Cloud       1141
# 4            DevOps       1061
# 5          Database        731
# 6     deep learning        702
# 7     Deep Learning        702

# %%
plt.figure(figsize=(10, 5))
plt.bar(top_skills_df['Skill'],top_skills_df['Job_Count'])
plt.title("Top 10 Skills Extracted from Job Descriptions")
plt.xlabel("Skills")
plt.ylabel("Number of Jobs")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # TF-IDF Analysis

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(
    max_features=1000,
    stop_words="english"
)

# %%
X = vectorizer.fit_transform(
    df["clean_description"])

# %%
print("TF-IDF Matrix Shape:", X.shape)
# Out:
# TF-IDF Matrix Shape: (16182, 187)

# %%
terms = vectorizer.get_feature_names_out()
scores = X.mean(axis=0).A1

# %%
tfidf_df = pd.DataFrame({"Term": terms,"TF_IDF_Score": scores})
tfidf_df = tfidf_df.sort_values("TF_IDF_Score",ascending=False)
tfidf_df.head(20)
# Out:
#             Term  TF_IDF_Score
# 62    experience      0.096767
# 159          sql      0.094176
# 134       python      0.081337
# 42          data      0.068506
# 167    technical      0.066125
# 55        docker      0.065915
# 139      related      0.065420
# 94      learning      0.061858
# 67           git      0.059558
# 128        power      0.055979
# 57      engineer      0.055800
# 154    solutions      0.053773
# 98       machine      0.053173
# 24      business      0.051313
# 79     improving      0.049499
# 91           key      0.049499
# 121  opportunity      0.049499
# 80       include      0.049499
# 84     involving      0.049499
# 75        hiring      0.049499

# %%
top_terms = tfidf_df.head(20)
plt.figure(figsize=(10, 6))
plt.bar(
    top_terms["Term"],
    top_terms["TF_IDF_Score"])

plt.title("Top 20 TF-IDF Terms in Job Descriptions")
plt.xlabel("Terms")
plt.ylabel("Average TF-IDF Score")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
taxonomy_lower = {
    skill.lower()
    for skill in skill_taxonomy}

tfidf_keywords = set(tfidf_df.head(50)["Term"].str.lower())

matched_skills = [
    skill for skill in tfidf_keywords
    if skill in taxonomy_lower]

print("TF-IDF Keywords:", len(tfidf_keywords))
print("Matched Dictionary Skills:", len(matched_skills))
print("\nMatched Skills:")
print(matched_skills)
# Out:
# TF-IDF Keywords: 50
# Matched Dictionary Skills: 1
#
# Matched Skills:
# ['nlp']

# %%
match_percentage = (len(matched_skills) / len(tfidf_keywords)) * 100
print(f"Dictionary Skills found in Top TF-IDF Keywords: "f"{match_percentage:.2f}%")
# Out:
# Dictionary Skills found in Top TF-IDF Keywords: 2.00%

# %% [markdown]
# TF-IDF can identify important terms automatically based on their statistical importance in job descriptions. However, it does not understand whether a term is actually a technical skill. Therefore, TF-IDF can discover useful skill-related keywords, but dictionary-based skill extraction is more reliable for identifying predefined technical skills.

# %% [markdown]
# # N-Gram Analysis

# %%
vectorizer = TfidfVectorizer(ngram_range=(1, 3),stop_words="english")

# %%
X = vectorizer.fit_transform(df["clean_description"])
print("Shape:", X.shape)
# Out:
# Shape: (16182, 8899)

# %%
terms = vectorizer.get_feature_names_out()
scores = X.mean(axis=0).A1
ngram_df = pd.DataFrame({"N-Gram": terms,"Score": scores})
ngram_df = ngram_df.sort_values("Score",ascending=False)
ngram_df.head(20)
# Out:
#                        N-Gram     Score
# 3032               experience  0.037191
# 7766                      sql  0.035961
# 6503                   python  0.030239
# 1660                     data  0.026128
# 8469                technical  0.025398
# 7069                  related  0.025218
# 2295                   docker  0.024826
# 5243                 learning  0.023861
# 6403                    power  0.022859
# 3714                      git  0.022623
# 2546                 engineer  0.021267
# 7576                solutions  0.020771
# 5617         machine learning  0.020440
# 5616                  machine  0.020440
# 1326                 business  0.019815
# 8825                     work  0.019019
# 7153                  results  0.019019
# 6441                 problems  0.019019
# 8827  work projects involving  0.019019
# 6229              opportunity  0.019019

# %%
bigram_vectorizer = TfidfVectorizer(ngram_range=(2, 2),stop_words="english")
bigram_X = bigram_vectorizer.fit_transform(df["clean_description"])
bigram_terms = bigram_vectorizer.get_feature_names_out()
bigram_scores = bigram_X.mean(axis=0).A1
bigram_df = pd.DataFrame({"Bigram": bigram_terms,"Score": bigram_scores})
bigram_df = bigram_df.sort_values("Score",ascending=False)
bigram_df.head(20)
# Out:
#                          Bigram     Score
# 821            machine learning  0.035470
# 1327              work projects  0.032857
# 622       improving performance  0.032857
# 746        key responsibilities  0.032857
# 1268         technical problems  0.032857
# 1070   responsibilities include  0.032857
# 1072         results experience  0.032857
# 1073              role requires  0.032857
# 963   performance communicating  0.032857
# 260       communicating results  0.032857
# 1137          solving technical  0.032857
# 979          projects involving  0.032857
# 978          problems improving  0.032857
# 1060      related qualification  0.032857
# 1032    qualification candidate  0.032857
# 1332           years experience  0.032776
# 1068             requires years  0.032155
# 972                    power bi  0.031703
# 1071                   rest api  0.030183
# 977              preferred time  0.028036

# %%
trigram_vectorizer = TfidfVectorizer(ngram_range=(3, 3),stop_words="english")
trigram_X = trigram_vectorizer.fit_transform(df["clean_description"])
trigram_terms = trigram_vectorizer.get_feature_names_out()
trigram_scores = trigram_X.mean(axis=0).A1
trigram_df = pd.DataFrame({"Trigram": trigram_terms,"Score": trigram_scores})
trigram_df = trigram_df.sort_values("Score",ascending=False)
trigram_df.head(20)
# Out:
#                                   Trigram     Score
# 7317              work projects involving  0.026503
# 6327           solving technical problems  0.026503
# 5332       problems improving performance  0.026503
# 1290     communicating results experience  0.026503
# 3461  improving performance communicating  0.026503
# 7034         technical problems improving  0.026503
# 5894      related qualification candidate  0.026503
# 4227         key responsibilities include  0.026503
# 5259    performance communicating results  0.026503
# 5990                  role requires years  0.025941
# 5906            requires years experience  0.025735
# 5331           preferred time opportunity  0.022618
# 5992        science related qualification  0.021373
# 1289         collaborate cross functional  0.019715
# 1294               cross functional teams  0.019715
# 1239             clean transform validate  0.019522
# 7220              transform validate data  0.019522
# 429         analyze business requirements  0.019398
# 5902       requirements convert technical  0.019398
# 1135        business requirements convert  0.019398

# %%
top_bigrams = bigram_df.head(10)
plt.figure(figsize=(10, 5))
plt.bar(top_bigrams["Bigram"],top_bigrams["Score"])
plt.title("Top 10 Bigrams in Job Descriptions")
plt.xlabel("Bigrams")
plt.ylabel("TF-IDF Score")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
print("Top Bigrams:")
print(bigram_df.head(20)["Bigram"].to_string(index=False))
print("\nTop Trigrams:")
print(trigram_df.head(20)["Trigram"].to_string(index=False))
# Out:
# Top Bigrams:
#          machine learning
#             work projects
#     improving performance
#      key responsibilities
#        technical problems
#  responsibilities include
#        results experience
#             role requires
# performance communicating
#     communicating results
#         solving technical
#        projects involving
#        problems improving
#     related qualification
#   qualification candidate
#          years experience
#            requires years
#                  power bi
#                  rest api
#            preferred time
#
# Top Trigrams:
#             work projects involving
#          solving technical problems
#      problems improving performance
#    communicating results experience
# improving performance communicating
#        technical problems improving
#     related qualification candidate
#        key responsibilities include
#   performance communicating results
#                 role requires years
#           requires years experience
#          preferred time opportunity
#       science related qualification
#        collaborate cross functional
#              cross functional teams
#            clean transform validate
#             transform validate data
#       analyze business requirements
#      requirements convert technical
#       business requirements convert

# %% [markdown]
# # Word Embeddings & Semantic Similarity

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
skill_names = list(skill_taxonomy.keys())
print("Skills:", skill_names)
print("Number of Skills:", len(skill_names))

skill_embeddings = model.encode(skill_names,convert_to_numpy=True)

print("Embedding Shape:", skill_embeddings.shape)
# Out:
# Skills: ['Programming', 'Database', 'Data Analytics', 'Machine Learning', 'Deep Learning', 'NLP', 'Cloud', 'Big Data', 'DevOps', 'Web Development', 'Data Engineering', 'Generative AI']
# Number of Skills: 12
# Embedding Shape: (12, 384)

# %%
skill_names = list(skill_taxonomy.keys())

print("Skills:", skill_names)
print("Number of Skills:", len(skill_names))
# Out:
# Skills: ['Programming', 'Database', 'Data Analytics', 'Machine Learning', 'Deep Learning', 'NLP', 'Cloud', 'Big Data', 'DevOps', 'Web Development', 'Data Engineering', 'Generative AI']
# Number of Skills: 12

# %%
skill_embeddings = model.encode(skill_names,convert_to_numpy=True)

print("Embedding Shape:", skill_embeddings.shape)
# Out:
# Embedding Shape: (12, 384)

# %%
job_description = df["job_description"].iloc[0]

# %%
job_description = df["clean_description"].iloc[0]

job_embedding = model.encode(job_description,convert_to_numpy=True)

print("Job Embedding Shape:", job_embedding.shape)
# Out:
# Job Embedding Shape: (384,)

# %%
similarity_scores = cosine_similarity(job_embedding.reshape(1, -1),skill_embeddings)[0]

print("Similarity Scores:", similarity_scores)
# Out:
# Similarity Scores: [0.2091054  0.21357358 0.26968235 0.10861616 0.10815655 0.00551362
#  0.01497068 0.1988136  0.17345005 0.21851411 0.2886777  0.07360478]

# %%
results = list(zip(skill_taxonomy, similarity_scores))

results = sorted(results,key=lambda x: x[1],reverse=True)
results[:20]
# Out:
# [('Data Engineering', np.float32(0.2886777)),
#  ('Data Analytics', np.float32(0.26968235)),
#  ('Web Development', np.float32(0.21851411)),
#  ('Database', np.float32(0.21357358)),
#  ('Programming', np.float32(0.2091054)),
#  ('Big Data', np.float32(0.1988136)),
#  ('DevOps', np.float32(0.17345005)),
#  ('Machine Learning', np.float32(0.10861616)),
#  ('Deep Learning', np.float32(0.10815655)),
#  ('Generative AI', np.float32(0.07360478)),
#  ('Cloud', np.float32(0.014970683)),
#  ('NLP', np.float32(0.005513616))]

# %%
threshold = 0.50

possible_skills = [
    (skill, round(float(score), 3))
    for skill, score in results
    if score >= threshold]

possible_skills
# Out:
# []

# %%
def find_possible_skills(text, threshold=0.50):

    job_embedding = model.encode(str(text),convert_to_numpy=True)

    scores = cosine_similarity([job_embedding],skill_embeddings)[0]

    results = [
        (skill, round(float(score), 3))
        for skill, score in zip(skill_taxonomy, scores)
        if score >= threshold]

    return sorted(results,key=lambda x: x[1],reverse=True)

# %%
df["semantic_skills"] = df["clean_description"].apply(find_possible_skills)

# %%
df[["job_title", "semantic_skills"]].head(10)
# Out:
#                    job_title semantic_skills
# 0           Business Analyst              []
# 1           Business Analyst              []
# 2  Machine Learning Engineer              []
# 3           Python Developer              []
# 4          Software Engineer              []
# 5           Business Analyst              []
# 6               NLP Engineer              []
# 7             Java Developer              []
# 8           Business Analyst              []
# 9           Python Developer              []

# %%
test_phrases = ["ML","Machine Learning"]

test_embeddings = model.encode(test_phrases,convert_to_numpy=True)

score = cosine_similarity([test_embeddings[0]],[test_embeddings[1]])[0][0]

print("ML vs Machine Learning Similarity:",round(float(score),3))
# Out:
# ML vs Machine Learning Similarity: 0.373

# %% [markdown]
# # Named Entity Recognition

# %%
text = df["clean_description"].iloc[0]
doc = nlp(text)
for ent in doc.ents:
    print(ent.text, "->", ent.label_)
# Out:
# deloitte -> ORG
# 1 3 years -> DATE
# sql jira statistics key -> ORG
# sql jira statistics -> ORG

# %%
def get_entities(text):
    doc = nlp(str(text))
    return [(ent.text, ent.label_) for ent in doc.ents]

# %%
df["standard_entities"] = df["clean_description"].apply(get_entities)

# %%
df[["job_title", "standard_entities"]].head(10)
# Out:
#                    job_title  \
# 0           Business Analyst
# 1           Business Analyst
# 2  Machine Learning Engineer
# 3           Python Developer
# 4          Software Engineer
# 5           Business Analyst
# 6               NLP Engineer
# 7             Java Developer
# 8           Business Analyst
# 9           Python Developer
#
#                                    standard_entities
# 0  [(deloitte, ORG), (1 3 years, DATE), (sql jira...
# 1                    [(5 8 years, DATE), (mca, ORG)]
# 2              [(deloitte, ORG), (8 12 years, DATE)]
# 3               [(1 3 years, DATE), (msc data, ORG)]
# 4  [(bengaluru, GPE), (2 5 years, DATE), (java do...
# 5  [(bengaluru, GPE), (8 12 years, DATE), (sql po...
# 6  [(ibm, ORG), (bengaluru, GPE), (3 6 years, DAT...
# 7  [(siemens, ORG), (1 3 years, DATE), (bsc, ORG)...
# 8  [(india, GPE), (5 8 years, DATE), (sql tableau...
# 9               [(siemens, ORG), (8 12 years, DATE)]

# %%
entity_categories = {
    "CLOUD_PLATFORM": [
        "AWS", "Azure", "GCP"
    ],

    "DATABASE": [
        "SQL", "MySQL", "PostgreSQL",
        "MongoDB", "Oracle"
    ],

    "TOOL": [
        "Power BI", "Tableau", "Excel",
        "Docker", "Kubernetes", "Git"
    ]
}

# %%
custom_entities = {}

for skill in skill_taxonomy:
    custom_entities[skill.lower()] = "SKILL"

for category, skills in entity_categories.items():
    for skill in skills:
        custom_entities[skill.lower()] = category

# %%
def extract_custom_entities(text):

    text = str(text)
    found = []

    for entity, label in custom_entities.items():

        pattern = r"\b" + re.escape(entity) + r"\b"

        if re.search(pattern, text, re.IGNORECASE):
            found.append((entity, label))

    return found

# %%
df["custom_entities"] = df["clean_description"].apply(extract_custom_entities)

# %%
df[["job_title","custom_entities"]].head(10)
# Out:
#                    job_title  \
# 0           Business Analyst
# 1           Business Analyst
# 2  Machine Learning Engineer
# 3           Python Developer
# 4          Software Engineer
# 5           Business Analyst
# 6               NLP Engineer
# 7             Java Developer
# 8           Business Analyst
# 9           Python Developer
#
#                                      custom_entities
# 0                [(sql, DATABASE), (power bi, TOOL)]
# 1  [(sql, DATABASE), (power bi, TOOL), (tableau, ...
# 2  [(machine learning, SKILL), (aws, CLOUD_PLATFO...
# 3                                   [(docker, TOOL)]
# 4                  [(sql, DATABASE), (docker, TOOL)]
# 5  [(sql, DATABASE), (power bi, TOOL), (tableau, ...
# 6          [(machine learning, SKILL), (nlp, SKILL)]
# 7                      [(docker, TOOL), (git, TOOL)]
# 8  [(sql, DATABASE), (power bi, TOOL), (tableau, ...
# 9                  [(sql, DATABASE), (docker, TOOL)]

# %%
entity_counts = Counter()

for entities in df["custom_entities"]:
    for skill, label in entities:
        entity_counts[label] += 1

print(entity_counts)
# Out:
# Counter({'TOOL': 16030, 'DATABASE': 10645, 'SKILL': 8485, 'CLOUD_PLATFORM': 3982})
